# %% [markdown]
# <a href="https://colab.research.google.com/github/MingChin100/python-ML/blob/master/dist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
samples = np.random.normal(local,size=10000)
sns.distplot(samples)

# %%
s = samples[samples > 0] + 1
sns.distplot(s)

# %%
from scipy.stats import skew
new = np.power(2,s)
sns.dis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tplot(new)
print("skew:", skew(new))
# Out:
# skew: 2.9789326921966013
